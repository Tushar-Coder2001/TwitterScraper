# %%
# !pip3 install -q snscrape

import os
from datetime import date
import pandas as pd

today=date.today()
end_date=today
print(end_date)


search_term='@crypto'   #Search 
from_date='2021-08-05'  #Date
max_results=100         #Results 


extracted_tweets = "snscrape --format '{content!r}'"+ f" --max-results {max_results} --since {from_date} twitter-search '{search_term} until:{end_date}' > extracted-tweets.txt"
os.system(extracted_tweets)
if os.stat("extracted-tweets.txt").st_size == 0:
  print('No Tweets found')
else:
  df = pd.read_csv('extracted-tweets.txt', names=['content'])
  for row in df['content'].iteritems():
    print(row)
# Out:
# 2022-08-28
# (0, "'@crypto thats new'")
# (1, "'@crypto @MagicCraftGame #MagicCraft $MCRT https://t.co/ywUegbtW8d'")
# (2, "'@crypto @VildanaHajric Market Cap is a ridiculous way to measure crypto")
# (3, "'@karanra29041598 @crypto Nice'")
# (4, "'@BasheerBhai10 @crypto 100% trying this!'")
# (5, "'@deepali_shende @crypto This ain’t bad'")
# (6, "'@crypto Thanks 🚀 \\nhttps://t.co/LAORgn5SDH...'")
# (7, "'In the affidavit")
# (8, "'@crypto Hell yeah'")
# (9, "'@str8edgeracer @crypto “Bloomberg crypto”'")
# (10, "'@crypto How many new coins have flooded the market since the evaluation. Whatever you think your numbers are. Their wrong'")
# (11, "'@Charlesnjobvu1 @crypto cool dude'")
# (12, "'@crypto Whyyy ain’t nobody talking about this????? https://t.co/jd8pSgqSpd……'")
# (13, "'@Mangesh39793414 @crypto I like the sound of this!'")
# (14, "'At a time when many crypto companies have seen their fortunes plummet")
# (15, "'@Amy_WilL_Amy @crypto From what I’ve seen")
# (16, "'@Shahnaw23641809 @crypto Tried this a few times")
# (17, "'@simidas51828923 @crypto Dude this looks awesome.'")
# (18, "'Looking for more news and analysis from the crypto team?\\n\\nSign up for the Bloomberg Crypto newsletter delivered straight to your inbox every Tuesday and Thursday: https://t.co/ImNbQwnQFF https://t.co/WFas6NMZeh'")
# (19, "'@crypto Where you get your info from 😏'")
# (20, "'@crypto NFT has no place in this industry'")
# (21, "'@HumpBackCrypto @crypto I was thinking the same thing. Love these articles lol'")
# (22, "'@str8edgeracer @crypto lol 🤡'")
# (23, "'@crypto uh wut?'")
# (24, "'@TheDustyBC Nothing is impossible in @Crypto'")
# (25, "'@crypto bitcoin Proof of Work is dead man walking. \\nSo much waste. insane.'")
# (26, "'@McTommy95 @crypto Gold Market cap is about $11.5 T'")
# (27, "&gt;was @crypto 's valuation ever worth more than 3 tril-\\n\\nno")
# (28, "'@crypto Me said it first.\\nhttps://t.co/mQUcfaNqhJ'")
# (29, "'@crypto https://t.co/zt5ZwV1tc7'")
# (30, "'@crypto more power")
# (31, "@Elonsoninu @crypto As for me I preach Diamond hands in #ESI patients is virtue for @Elonsoninu and he wo stay calm and patient meet the good news of #Elonsoninu.... Let's go guys")
# (32, "'@crypto Sorry dudee")
# (33, "'@SurajSi81251944 @crypto Definitely giving this a go!'")
# (34, "'@TheDustyBC @crypto is life'")
# (35, "'@crypto why nbodyyy talkk about this https://t.co/x9PSQ2JcUM'")
# (36, "'Crypto currency miners are accelerating their push to expand in Texas far beyond what authorities had initially expected")
# (37, "'What do you guys think about the blockchain and nft games?\\n\\n@cryptoidleminer @crypto @GalaxyFight_NFT @Rogues_nft @SpazzNft @CyberlinxNFT @DropYourNFT @MonsterGO_NFT @TheTokenMiner @BCGameInfo_EN \\n@blockchaingaming @blockchaindeveloper'")
# (38, "'@crypto I doubt it!'")
# (39, "'@crypto Why so much attention to Tornado Cash now? Is this all after the wallet freeze?'")
# (40, "'@TheImpaler83 @crypto @CelerNetwork You are quite right'")
# (41, "'@magicsimpson0 @crypto @aeon7 @CryptoMatt87 @chirocrypto @AltMasterRoshi LFG'")
# (42, "'@OlegLurie @crypto ТАМ ЕСЛЙ КТО ТА НЙ ЗНАЙТ КАК ВЫГЛЙДЙТ АБЙЖЫНЫЙ ПЙДАРАСТ ПЯНЫФ РЫЖЫИ ПЯНЫЙ СОСКА ВОТ СОСКА ЭТА ПЙДАР'")
# (43, "'@crypto *laugh in DW2010-2015*'")
# (44, "'@Masudmo87732069 @crypto Can someone show me how to do this??'")
# (45, "'@crypto Whyy is the media silentt on thiss??? https://t.co/n9k2HcudF8….'")
# (46, "'@deepali_shende @crypto Interesting!'")
# (47, "Tornado Cash was “the laundering tool of choice’' for NFT scams before being sanctioned, Elliptic said in a new report https://t.co/Oxc1FXyhU2")
# (48, "'@DrifterXmr @crypto Capital flight.'")
# (49, "'@crypto Is it going to be closed randomly just like #solana’s #blockchain ?'")
# (50, "'@crypto It might have been $3 Trillion")
# (51, "'@crypto Thankss 🚀 \\n\\nhttps://t.co/I6KHiTf6ZJ..'")
# (52, "'There’s now an IRL store in New York dedicated to the Solana blockchain. But why? https://t.co/z6FQbux3jo'")
# (53, "'@magicsimpson0 @crypto @aeon7 @CryptoMatt87 @chirocrypto @AltMasterRoshi https://t.co/D5Fpg929tX'")
# (54, "'@KiwanoSwap @crypto @kivanocrowdsale'")
# (55, "'@crypto Ponzis have never been that hot. So much is true. #cryptocurrecy'")
# (56, "'@crypto Thanks 🚀 \\nhttps://t.co/WAnsRh89J7...'")
# (57, "'@Alex58131804 @crypto Dude this looks awesome.'")
# (58, "'@crypto How comee the media isn’t reportinn this????? https://t.co/Av3RmAEw8g…….'")
# (59, "'The crypto universe is expanding fast")
# (60, "'#bolkazanç #btc #eth #binance @crypto #bolkazanç Güzel bir proje yakaladım ilgilenenler DM ye minimum giriş 80$ ve 26 doları benden size hediye 🤪'")
# (61, "'@crypto #EThgate https://t.co/aX7r6BDKWY'")
# (62, "'@BeckyHu99198316 @dan0foster @crypto Honestly")
# (63, "'@magicsimpson0 @crypto @aeon7 @CryptoMatt87 @chirocrypto @AltMasterRoshi Meme potential is off the charts'")
# (64, "MagicSimpson is now live. It's a low tax play made for the community.\\n\\n#cryptocurrecy #100x #1000x #moonshot #lowtax\\n\\n@Crypto @Aeon7 @CryptoMatt87 @chirocrypto @AltMasterRoshi https://t.co/6QbOxLKThs")
# (65, "'@crypto @Lizzie Martun'")
# (66, "'@crypto Thanks 🚀 \\nhttps://t.co/w5moMPigtF...'")
# (67, "'@crypto #bitcoin bear 8 k?'")
# (68, "'@ShawnaNix7 @crypto I was posting about this and now I tried and it worked'")
# (69, "'@ShawnaNix7 @crypto Keep posting these profitable videos'")
# (70, "'@crypto There is nothing better than this on Twitter??  https://t.co/dcmWo7NByZ'")
# (71, "'The non-profit foundation behind the Ethereum blockchain is quadrupling the rewards it will pay to friendly hackers who uncover bugs in the code of its much ballyhooed software upgrade to as much as $1 million https://t.co/l57UakNS88'")
# (72, "'@crypto @Lzzie Martin'")
# (73, "'@crypto Top G project @Ricky_361 @HenrikPiga @jonah_jpg'")
# (74, "'@ger313 @ewarren @_CryptoCurator @mattysats @alexandre_lores @CNBCFastMoney @crypto 🔥🔥 Why influencers hide this https://t.co/hM3P8m7Prj'")
# (75, "'286 M RECOVERED IN COVID SCAMS! Oh what’s that you say another fucking huge scam that has nothing to do with bitcoin oh fucking shocking! #BTC .@ewarren @_CryptoCurator @mattysats @alexandre_lores @CNBCFastMoney @crypto https://t.co/qj9uRctzOy'")
# (76, "'There is an extremely strong support for #bitcoin which prevents against further fall - at the level of #USD 20")
# (77, "'@crypto #Ethereum? What is that? I don’t care.'")
# (78, "'@crypto The closer crypto gets to the dollar")
# (79, "'@crypto Celer Network should rage 😤 @CelerNetwork #VALUE #UTILITY #GREATTEAM'")
# (80, "'@crypto @Luzzie Martin'")
# (81, "'@crypto 🚀 Thnks a millon. \\n\\nhttps://t.co/aBMdxG5wQq..'")
# (82, "'Two decades later")
# (83, "'@VNSMART3 @BTCTN @MarketWatch @ethereum @HuobiGlobal @crypto @BitcoinMagazine 인출요청후 몇일이 지났는데 아직도 심사중이다. 언제 심사가 끝나.\\n그리고 인출 지연으로 인한 보상은?'")
# (84, "Is #Flippening on Horizon? Fans of #Ether have fingers crossed that the token could eventually overtake Bitcoin; What would the future of #crypto look like if #Ethereum overtakes #Bitcoin as the world's largest cryptocurrency? https://t.co/IHyca3cnY5 @crypto.@business $ETH $BTC")
# (85, "'@crypto @Lizzie  Martin'")
# (86, "'#Blockchain #Ethereum #web3 #Bitcoin #Freedom \\n\\n@crypto @CNN @cnnbrk @cnni @FoxNews @BfmCrypto @BFMTV @markets  @CBC @nytimes @TheSun @Cointelegraph @LeJournalDuCoin @coinbureau @DailyMail @Yomiuri_Online @asahi @thetimes @TheTimesofMalta @thetimesofindia @WSJ @WSJTech @WSJTech https://t.co/tj99KqcUQf'")
# (87, "'@pedersahii @crypto Neymiş la o'")
# (88, "'@crypto Thank you @Strategic_Funds \\n@MXLESQ'")
# (89, "'@crypto @Lizzie Martin'")
# (90, "'@fagunosefeimora @enifome @business @PiCoreTeam @crypto yeah man you can try this'")
# (91, "'Top 10 Cryptocurrencies in the World by Twitter Followers (27/AUG/2022)\\n\\n1. #BNB\\xa0 9.35M \\n2. #Bitcoin\\xa0\\xa0 5.48M\\n3. #Shib 3.46M\\n4. #Dogecoin 3.44M\\n5. #Ethereum 2.79M \\n6. #XRP 2.52M\\n7. #CRO\\xa0 2.51M\\n8. #Solana 2.01M \\n9. #PiNetwork 1.62M \\n10. #Polygon 1.62M @business @PiCoreTeam @crypto https://t.co/NFovsUvcXw'")
# (92, "'@skyline2lt @crypto Agreed")
# (93, "'@crypto Thanks 🚀 \\nhttps://t.co/lcSrdIX5JG...'")
# (94, "'Some of the world’s biggest trading houses and crypto firms are backing a startup that aims to ease Wall Street’s entry into crypto trading by tackling counterparty risks and conflicts of interest https://t.co/fw2tuoexLx'")
# (95, "@crypto the best up and coming project is @Chronolyio, they're going to change how we invest in watches today as well as the NFT field give the page a brief glance, I believe in them you should too. #watchthisspace https://t.co/YYcPxXB1wl")
# (96, "'I know that there are some of you with huge #Tonic bags")
# (97, "'@crypto @olgakharif @emilychangtv Why do you need security for worthless shit'")
# (98, "'@Liberti18066769 @crypto This will make it easier for governments to control ethereum. ETH stakers are large entities that will bow to ofac and censor transactions.'")
# (99, "'@crypto Hope this merge is going to be great'")
